# %% [markdown]
# # Distribution plots

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# Get tips database from seaborn

# %%
tips = sns.load_dataset('tips')

# %%
tips.to_csv('tips.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])

# %% [markdown]
# Get a histogram and a KDE (kernel density estimation)

# %%
sns.distplot(tips['total_bill'], kde=False)

# %% [markdown]
# Bins (groupings) at 10 dollar intervals, can change

# %%
sns.distplot(tips['total_bill'], kde=False, bins=30)

# %% [markdown]
# ### Jointplot

# %% [markdown]
# Match up two dist plots for bivariate data

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind='kde')

# %% [markdown]
# ##### 2D kde, allows one to see the density of where points match up

# %% [markdown]
# ## Pairplot

# %% [markdown]
# Pairwise relationships across entire DataFrame (numerical Columns).
# But also supports colour hue argument for categorical columns

# %% [markdown]
# Think of pairplot as doing jointplot for every possible combination of numerical columns in DF

# %%
sns.pairplot(tips)

# %% [markdown]
# Note that paremeter vs. itself, provides histogram

# %% [markdown]
# Quick visualization tool

# %% [markdown]
# ##### can use hue argument to put categorical variables on legend

# %%
sns.pairplot(tips, hue='sex')

# %% [markdown]
# Can use the palette variable to customize colours

# %%
sns.pairplot(tips,hue='sex',palette=('coolwarm'))

# %% [markdown]
# # Rugplots

# %% [markdown]
# Simple dash plot

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'])

# %% [markdown]
# Example to show relationship between rug plot and KDE

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
#create a dataset

dataset = np.random.randn(25)

#create rugplot
sns.rugplot(dataset)

#set up x axis
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

#Set up the bandwidth following the rule of thumb found in:
URL = 'https://en.wikipedia.org/wiki/Kernel_density_estimation#A_rule-of-thumb_bandwidth_estimator'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2

#Create an empty kernel list
kernel_list = []

#Plot each basis function
for data_point in dataset:
    
    #Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis, kernel, color='grey', alpha=0.5)
    
plt.ylim(0,1)
# Out:
# (0, 1)

# %% [markdown]
# We plot a normal distribution centered around each of the dashes (data points)

# %% [markdown]
# Now we will sum them up to get the kernel density basis function

# %%
# To get the kde plot we can sum these basis functions

# Plot the sum of the basis functions
sum_of_kde = np.sum(kernel_list, axis=0)

# Plot figure
fig = plt.plot(x_axis, sum_of_kde, color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c='indianred')

# get rid of y-tick marks
plt.yticks([])

#Set title
plt.suptitle('Sum of the Basis Functions')
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Functions')

# %%
sns.kdeplot(tips['total_bill'])
